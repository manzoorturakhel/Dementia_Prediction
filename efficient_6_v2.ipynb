# %% [markdown]
# <a href="https://colab.research.google.com/github/manzoorturakhel/Dementia_Prediction/blob/main/efficient_6_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
path=drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile as zf
files = zf.ZipFile("/content/drive/MyDrive/dataset.zip", 'r')
files.extractall('')
files.close()

# %%
# importing important libraries

import torch
from torch import nn

import torchvision
from torchvision import transforms,datasets, models
from torchvision.transforms import ToTensor, v2

from torch.utils.data import DataLoader, random_split, Dataset

from imblearn.over_sampling import SMOTE




import matplotlib.pyplot  as plt

from tqdm.auto import tqdm

import os

from pathlib import Path

# %%
# checking if gpu is available

if torch.cuda.is_available():
    device = "cuda" # NVIDIA GPU
# elif torch.backends.mps.is_available():
#     device = "mps" # Apple GPU
else:
    device = "cpu" # Defaults to CPU if NVIDIA GPU/Apple GPU aren't available

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# lets prepare our data for training and testing and do some EDA
import numpy as np
from imblearn.over_sampling import SMOTE
from torch.utils.data import TensorDataset, DataLoader
import torch
root_dir= "Alzheimer_s Dataset"
train_dir = os.path.join(root_dir,'train')

simple_transform = v2.Compose([
    v2.Grayscale(num_output_channels=1),
    v2.ToTensor(),
])

transform = v2.Compose([


        v2.ColorJitter(brightness=0.5),  # Brightness adjustment


        v2.RandomAffine(degrees=0, scale=(0.98, 1.2)), # Zooming


        v2.Pad(padding=5, fill=0),  # Filling (padding with zeros)

    v2.RandomHorizontalFlip(p=0.4),  # Flipping
    v2.RandomAdjustSharpness(sharpness_factor=2,p=0.5),
    v2.Resize((160, 160)),  # Rescaling
    v2.CenterCrop(size=(150,150)),
    # v2.Grayscale(num_output_channels=1),
    v2.ToTensor(),



])
simple_train_data =  datasets.ImageFolder(train_dir,transform=simple_transform)
# now that we have sat the train and test directories we will prepare it to make it as a dataset using datasets.ImageFolder
train_data = datasets.ImageFolder(train_dir,transform=transform)

train_size = int(0.7 * len(train_data))
val_size = int(0.15 * len(train_data))
test_size = len(train_data) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(train_data, [train_size, val_size, test_size])





# let check the data now
print(len(train_data.samples)) #

class_names = train_data.classes
class_idx = train_data.class_to_idx


batch_size = 50

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 6400
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
 root_dir= "Alzheimer_s Dataset"
 for dirpath, dirnames, filenames in os.walk(root_dir):
  print(f" directory name:{dirnames} files lens:{len(filenames)}")
# Out:
#  directory name:['train'] files lens:1
#  directory name:['MildDemented', 'VeryMildDemented', 'ModerateDemented', 'NonDemented'] files lens:1
#  directory name:[] files lens:896
#  directory name:[] files lens:2240
#  directory name:[] files lens:64
#  directory name:[] files lens:3200

# %%
# befor applying SMOTE imbalance classes
MildDemented = os.path.join(train_dir,'MildDemented')
ModerateDemented= os.path.join(train_dir,'ModerateDemented')
VeryMildDemented=os.path.join(train_dir,'VeryMildDemented')
NonDemented=os.path.join(train_dir,'NonDemented')


num_of_classes_in_training =  {
    'MildD':len(os.listdir(MildDemented)),
    'ModerateD':len(os.listdir(ModerateDemented)),
    'VeryMildD':len(os.listdir(VeryMildDemented)),
    'NonD':len(os.listdir(NonDemented))
}
print(num_of_classes_in_training)
plt.bar(num_of_classes_in_training.keys(),num_of_classes_in_training.values(),color=['black','red','green','blue']);
plt.title('class numbers');
# Out:
# {'MildD': 896, 'ModerateD': 64, 'VeryMildD': 2240, 'NonD': 3200}

# %%
print(len(train_loader.dataset))
print(type(train_data.classes))
# Out:
# 4480
# <class 'list'>

# %%
# applying SMOTE to balance classes and see whether it improves the performance

X = []
y = []
for img, label in train_data:
    X.append(img.numpy().flatten())  # Flatten the image
    y.append(label)

X = np.array(X)
y = np.array(y)

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Convert back to PyTorch tensors
X_resampled = torch.from_numpy(X_resampled).float().view(-1, 3, 150, 150)  # Reshape back to image format
y_resampled = torch.from_numpy(y_resampled).long()

# Create a new TensorDataset
balanced_dataset = TensorDataset(X_resampled, y_resampled)




class TransformedTensorDataset(Dataset):
    def __init__(self, tensor_dataset, transform=None):
        self.tensor_dataset = tensor_dataset
        self.transform = transform

    def __getitem__(self, index):
        img, label = self.tensor_dataset[index]

        # Convert tensor to PIL Image for transforms
        img = transforms.ToPILImage()(img)

        if self.transform:
            img = self.transform(img)

        return img, label

    def __len__(self):
        return len(self.tensor_dataset)

# # Create the transformed dataset
transformed_balanced_dataset = TransformedTensorDataset(balanced_dataset, transform=transform)

# print(len(transformed_balanced_dataset))

# %%
print(type(balanced_dataset.tensors),type(train_data.imgs))
# Out:
# <class 'tuple'> <class 'list'>

# %%
print(len(transformed_balanced_dataset))

# splitting the new data between train,validation and test


train_size = int(0.7 * len(transformed_balanced_dataset))
val_size = int(0.15 * len(transformed_balanced_dataset))
test_size = len(transformed_balanced_dataset) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(transformed_balanced_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)





# let check the data now
print(len(transformed_balanced_dataset.tensor_dataset))

class_names = train_data.classes
class_idx = train_data.class_to_idx
# Out:
# 12800
# 12800

# %%
# after applying smote


unique, counts = np.unique(y_resampled, return_counts=True)

unique,counts
# new number of sample per class object
new_number_of_classes={}


for i in range(len(unique)):
  new_number_of_classes[class_names[i]] = counts[i]


new_number_of_classes

# Plot the bar graph
plt.figure(figsize=(10, 5))
plt.bar(new_number_of_classes.keys(), new_number_of_classes.values(), color=['red','black','green','blue'])
plt.xlabel('Class')
plt.ylabel('Number of samples')
plt.title('Number of Samples per Class after SMOTE')
plt.show()

# %%
print(type(train_data.imgs))
# Out:
# <class 'list'>

# %%
# let visualize images after and before data augmentation

plt.figure(figsize=(7,6))

image,label  = simple_train_data[5]

# augmented data
image1,label1 = train_data[5]

print(image.shape)

plt.subplot(1,2,1)
plt.imshow(image.permute(1, 2, 0),cmap='gray');
plt.title(f" before prep:{class_names[label]}")
plt.axis(False)
plt.subplot(1,2,2)
plt.imshow(image1.permute(1, 2, 0),cmap='gray');
plt.title(f" after prep:{class_names[label1]}")
plt.axis(False)
# Out:
# torch.Size([1, 208, 176])
# (-0.5, 149.5, 149.5, -0.5)

# %%
# let visualize some random images from the dataset
def displayRandomImage(data,nrows:int=4,ncols:int=4):
  """
  data will be from train1 and train2 to see the difference
  nrows are number of rows and by default it will be 4 unless specified
  ncols are number of cols and by default it will be 4 unless specified
  """
  plt.figure(figsize=(9,9))
  torch.manual_seed(42)

  for i in range(1,nrows*ncols+1):

    random_idx = torch.randint(0,len(data),size=[1]).item()
    image,label = data[random_idx]
    plt.subplot(nrows,ncols,i)
    plt.imshow(image.permute(1, 2, 0),cmap='gray');
    plt.title(class_names[label]);
    plt.axis(False);

# %%
print("images before preprocessing.....\n")

displayRandomImage(simple_train_data)
# Out:
# images before preprocessing.....

# %%
print("images after preprocessing.....\n")

displayRandomImage(train_data)
# Out:
# images after preprocessing.....

# %%
# pip install torchsampler
weights = torchvision.models.EfficientNet_B6_Weights.DEFAULT# .DEFAULT = best available weights
model1 = torchvision.models.efficientnet_b6(weights=weights).to(device)

# %%
try:
  import torchinfo
except:
  # !pip install torchinfo
  import torchinfo

# %%
# model1 = customCNN(input_shape=1,filters=32,output_shape=4).to(device)
from torchinfo import summary
summary(model=model1,
        input_size=(50, 3, 150, 150), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)

model1.classifier
# Out:
# Sequential(
#   (0): Dropout(p=0.5, inplace=True)
#   (1): Linear(in_features=2304, out_features=1000, bias=True)
# )

# %%
for param in model1.parameters():
    param.requires_grad = False



# unfreezing layer3 and layer 4
for layer in [model1.features[5], model1.features[6],model1.features[7],model1.features[8]]:
    for param in layer.parameters():
        param.requires_grad = True

# Verifying
for name, param in model1.named_parameters():
    if param.requires_grad:
        print(f"Unfrozen layer: {name}")
model1.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.5, inplace=True),
    torch.nn.Linear(in_features=2304, out_features=4),


    ).to(device)
# Out:
# Unfrozen layer: features.5.0.block.0.0.weight
# Unfrozen layer: features.5.0.block.0.1.weight
# Unfrozen layer: features.5.0.block.0.1.bias
# Unfrozen layer: features.5.0.block.1.0.weight
# Unfrozen layer: features.5.0.block.1.1.weight
# Unfrozen layer: features.5.0.block.1.1.bias
# Unfrozen layer: features.5.0.block.2.fc1.weight
# Unfrozen layer: features.5.0.block.2.fc1.bias
# Unfrozen layer: features.5.0.block.2.fc2.weight
# Unfrozen layer: features.5.0.block.2.fc2.bias
# Unfrozen layer: features.5.0.block.3.0.weight
# Unfrozen layer: features.5.0.block.3.1.weight
# Unfrozen layer: features.5.0.block.3.1.bias
# Unfrozen layer: features.5.1.block.0.0.weight
# Unfrozen layer: features.5.1.block.0.1.weight
# Unfrozen layer: features.5.1.block.0.1.bias
# Unfrozen layer: features.5.1.block.1.0.weight
# Unfrozen layer: features.5.1.block.1.1.weight
# Unfrozen layer: features.5.1.block.1.1.bias
# Unfrozen layer: features.5.1.block.2.fc1.weight
# Unfrozen layer: features.5.1.block.2.fc1.bias
# Unfrozen layer: features.5.1.block.2.fc2.weight
# Unfrozen layer: features.5.1.block.2.fc2.bias
# Unfrozen layer: features.5.1.block.3.0.weight
# Unfrozen layer: features.5.1.block.3.1.weight
# Unfrozen layer: features.5.1.block.3.1.bias
# Unfrozen layer: features.5.2.block.0.0.weight
# Unfrozen layer: features.5.2.block.0.1.weight
# Unfrozen layer: features.5.2.block.0.1.bias
# Unfrozen layer: features.5.2.block.1.0.weight
# Unfrozen layer: features.5.2.block.1.1.weight
# Unfrozen layer: features.5.2.block.1.1.bias
# Unfrozen layer: features.5.2.block.2.fc1.weight
# Unfrozen layer: features.5.2.block.2.fc1.bias
# Unfrozen layer: features.5.2.block.2.fc2.weight
# Unfrozen layer: features.5.2.block.2.fc2.bias
# Unfrozen layer: features.5.2.block.3.0.weight
# Unfrozen layer: features.5.2.block.3.1.weight
# Unfrozen layer: features.5.2.block.3.1.bias
# Unfrozen layer: features.5.3.block.0.0.weight
# Unfrozen layer: features.5.3.block.0.1.weight
# Unfrozen layer: features.5.3.block.0.1.bias
# Unfrozen layer: features.5.3.block.1.0.weight
# Unfrozen layer: features.5.3.block.1.1.weight
# Unfrozen layer: features.5.3.block.1.1.bias
# Unfrozen layer: features.5.3.block.2.fc1.weight
# Unfrozen layer: features.5.3.block.2.fc1.bias
# Unfrozen layer: features.5.3.block.2.fc2.weight
# Unfrozen layer: features.5.3.block.2.fc2.bias
# Unfrozen layer: features.5.3.block.3.0.weight
# Unfrozen layer: features.5.3.block.3.1.weight
# Unfrozen layer: features.5.3.block.3.1.bias
# Unfrozen layer: features.5.4.block.0.0.weight
# Unfrozen layer: features.5.4.block.0.1.weight
# Unfrozen layer: features.5.4.block.0.1.bias
# Unfrozen layer: features.5.4.block.1.0.weight
# Unfrozen layer: features.5.4.block.1.1.weight
# Unfrozen layer: features.5.4.block.1.1.bias
# Unfrozen layer: features.5.4.block.2.fc1.weight
# Unfrozen layer: features.5.4.block.2.fc1.bias
# Unfrozen layer: features.5.4.block.2.fc2.weight
# Unfrozen layer: features.5.4.block.2.fc2.bias
# Unfrozen layer: features.5.4.block.3.0.weight
# Unfrozen layer: features.5.4.block.3.1.weight
# Unfrozen layer: features.5.4.block.3.1.bias
# Unfrozen layer: features.5.5.block.0.0.weight
# Unfrozen layer: features.5.5.block.0.1.weight
# Unfrozen layer: features.5.5.block.0.1.bias
# Unfrozen layer: features.5.5.block.1.0.weight
# Unfrozen layer: features.5.5.block.1.1.weight
# Unfrozen layer: features.5.5.block.1.1.bias
# Unfrozen layer: features.5.5.block.2.fc1.weight
# Unfrozen layer: features.5.5.block.2.fc1.bias
# Unfrozen layer: features.5.5.block.2.fc2.weight
# Unfrozen layer: features.5.5.block.2.fc2.bias
# Unfrozen layer: features.5.5.block.3.0.weight
# Unfrozen layer: features.5.5.block.3.1.weight
# Unfrozen layer: features.5.5.block.3.1.bias
# Unfrozen layer: features.5.6.block.0.0.weight
# Unfrozen layer: features.5.6.block.0.1.weight
# Unfrozen layer: features.5.6.block.0.1.bias
# Unfrozen layer: features.5.6.block.1.0.weight
# Unfrozen layer: features.5.6.block.1.1.weight
# Unfrozen layer: features.5.6.block.1.1.bias
# Unfrozen layer: features.5.6.block.2.fc1.weight
# Unfrozen layer: features.5.6.block.2.fc1.bias
# Unfrozen layer: features.5.6.block.2.fc2.weight
# Unfrozen layer: features.5.6.block.2.fc2.bias
# Unfrozen layer: features.5.6.block.3.0.weight
# Unfrozen layer: features.5.6.block.3.1.weight
# Unfrozen layer: features.5.6.block.3.1.bias
# Unfrozen layer: features.5.7.block.0.0.weight
# Unfrozen layer: features.5.7.block.0.1.weight
# Unfrozen layer: features.5.7.block.0.1.bias
# Unfrozen layer: features.5.7.block.1.0.weight
# Unfrozen layer: features.5.7.block.1.1.weight
# Unfrozen layer: features.5.7.block.1.1.bias
# Unfrozen layer: features.5.7.block.2.fc1.weight
# Unfrozen layer: features.5.7.block.2.fc1.bias
# Unfrozen layer: features.5.7.block.2.fc2.weight
# Unfrozen layer: features.5.7.block.2.fc2.bias
# Unfrozen layer: features.5.7.block.3.0.weight
# Unfrozen layer: features.5.7.block.3.1.weight
# Unfrozen layer: features.5.7.block.3.1.bias
# Unfrozen layer: features.6.0.block.0.0.weight
# Unfrozen layer: features.6.0.block.0.1.weight
# Unfrozen layer: features.6.0.block.0.1.bias
# Unfrozen layer: features.6.0.block.1.0.weight
# Unfrozen layer: features.6.0.block.1.1.weight
# Unfrozen layer: features.6.0.block.1.1.bias
# Unfrozen layer: features.6.0.block.2.fc1.weight
# Unfrozen layer: features.6.0.block.2.fc1.bias
# Unfrozen layer: features.6.0.block.2.fc2.weight
# Unfrozen layer: features.6.0.block.2.fc2.bias
# Unfrozen layer: features.6.0.block.3.0.weight
# Unfrozen layer: features.6.0.block.3.1.weight
# Unfrozen layer: features.6.0.block.3.1.bias
# Unfrozen layer: features.6.1.block.0.0.weight
# Unfrozen layer: features.6.1.block.0.1.weight
# Unfrozen layer: features.6.1.block.0.1.bias
# Unfrozen layer: features.6.1.block.1.0.weight
# Unfrozen layer: features.6.1.block.1.1.weight
# Unfrozen layer: features.6.1.block.1.1.bias
# Unfrozen layer: features.6.1.block.2.fc1.weight
# Unfrozen layer: features.6.1.block.2.fc1.bias
# Unfrozen layer: features.6.1.block.2.fc2.weight
# Unfrozen layer: features.6.1.block.2.fc2.bias
# Unfrozen layer: features.6.1.block.3.0.weight
# Unfrozen layer: features.6.1.block.3.1.weight
# Unfrozen layer: features.6.1.block.3.1.bias
# Unfrozen layer: features.6.2.block.0.0.weight
# Unfrozen layer: features.6.2.block.0.1.weight
# Unfrozen layer: features.6.2.block.0.1.bias
# Unfrozen layer: features.6.2.block.1.0.weight
# Unfrozen layer: features.6.2.block.1.1.weight
# Unfrozen layer: features.6.2.block.1.1.bias
# Unfrozen layer: features.6.2.block.2.fc1.weight
# Unfrozen layer: features.6.2.block.2.fc1.bias
# Unfrozen layer: features.6.2.block.2.fc2.weight
# Unfrozen layer: features.6.2.block.2.fc2.bias
# Unfrozen layer: features.6.2.block.3.0.weight
# Unfrozen layer: features.6.2.block.3.1.weight
# Unfrozen layer: features.6.2.block.3.1.bias
# Unfrozen layer: features.6.3.block.0.0.weight
# Unfrozen layer: features.6.3.block.0.1.weight
# Unfrozen layer: features.6.3.block.0.1.bias
# Unfrozen layer: features.6.3.block.1.0.weight
# Unfrozen layer: features.6.3.block.1.1.weight
# Unfrozen layer: features.6.3.block.1.1.bias
# Unfrozen layer: features.6.3.block.2.fc1.weight
# Unfrozen layer: features.6.3.block.2.fc1.bias
# Unfrozen layer: features.6.3.block.2.fc2.weight
# Unfrozen layer: features.6.3.block.2.fc2.bias
# Unfrozen layer: features.6.3.block.3.0.weight
# Unfrozen layer: features.6.3.block.3.1.weight
# Unfrozen layer: features.6.3.block.3.1.bias
# Unfrozen layer: features.6.4.block.0.0.weight
# Unfrozen layer: features.6.4.block.0.1.weight
# Unfrozen layer: features.6.4.block.0.1.bias
# Unfrozen layer: features.6.4.block.1.0.weight
# Unfrozen layer: features.6.4.block.1.1.weight
# Unfrozen layer: features.6.4.block.1.1.bias
# Unfrozen layer: features.6.4.block.2.fc1.weight
# Unfrozen layer: features.6.4.block.2.fc1.bias
# Unfrozen layer: features.6.4.block.2.fc2.weight
# Unfrozen layer: features.6.4.block.2.fc2.bias
# Unfrozen layer: features.6.4.block.3.0.weight
# Unfrozen layer: features.6.4.block.3.1.weight
# Unfrozen layer: features.6.4.block.3.1.bias
# Unfrozen layer: features.6.5.block.0.0.weight
# Unfrozen layer: features.6.5.block.0.1.weight
# Unfrozen layer: features.6.5.block.0.1.bias
# Unfrozen layer: features.6.5.block.1.0.weight
# Unfrozen layer: features.6.5.block.1.1.weight
# Unfrozen layer: features.6.5.block.1.1.bias
# Unfrozen layer: features.6.5.block.2.fc1.weight
# Unfrozen layer: features.6.5.block.2.fc1.bias
# Unfrozen layer: features.6.5.block.2.fc2.weight
# Unfrozen layer: features.6.5.block.2.fc2.bias
# Unfrozen layer: features.6.5.block.3.0.weight
# Unfrozen layer: features.6.5.block.3.1.weight
# Unfrozen layer: features.6.5.block.3.1.bias
# Unfrozen layer: features.6.6.block.0.0.weight
# Unfrozen layer: features.6.6.block.0.1.weight
# Unfrozen layer: features.6.6.block.0.1.bias
# Unfrozen layer: features.6.6.block.1.0.weight
# Unfrozen layer: features.6.6.block.1.1.weight
# Unfrozen layer: features.6.6.block.1.1.bias
# Unfrozen layer: features.6.6.block.2.fc1.weight
# Unfrozen layer: features.6.6.block.2.fc1.bias
# Unfrozen layer: features.6.6.block.2.fc2.weight
# Unfrozen layer: features.6.6.block.2.fc2.bias
# Unfrozen layer: features.6.6.block.3.0.weight
# Unfrozen layer: features.6.6.block.3.1.weight
# Unfrozen layer: features.6.6.block.3.1.bias
# Unfrozen layer: features.6.7.block.0.0.weight
# Unfrozen layer: features.6.7.block.0.1.weight
# Unfrozen layer: features.6.7.block.0.1.bias
# Unfrozen layer: features.6.7.block.1.0.weight
# Unfrozen layer: features.6.7.block.1.1.weight
# Unfrozen layer: features.6.7.block.1.1.bias
# Unfrozen layer: features.6.7.block.2.fc1.weight
# Unfrozen layer: features.6.7.block.2.fc1.bias
# Unfrozen layer: features.6.7.block.2.fc2.weight
# Unfrozen layer: features.6.7.block.2.fc2.bias
# Unfrozen layer: features.6.7.block.3.0.weight
# Unfrozen layer: features.6.7.block.3.1.weight
# Unfrozen layer: features.6.7.block.3.1.bias
# Unfrozen layer: features.6.8.block.0.0.weight
# Unfrozen layer: features.6.8.block.0.1.weight
# Unfrozen layer: features.6.8.block.0.1.bias
# Unfrozen layer: features.6.8.block.1.0.weight
# Unfrozen layer: features.6.8.block.1.1.weight
# Unfrozen layer: features.6.8.block.1.1.bias
# Unfrozen layer: features.6.8.block.2.fc1.weight
# Unfrozen layer: features.6.8.block.2.fc1.bias
# Unfrozen layer: features.6.8.block.2.fc2.weight
# Unfrozen layer: features.6.8.block.2.fc2.bias
# Unfrozen layer: features.6.8.block.3.0.weight
# Unfrozen layer: features.6.8.block.3.1.weight
# Unfrozen layer: features.6.8.block.3.1.bias
# Unfrozen layer: features.6.9.block.0.0.weight
# Unfrozen layer: features.6.9.block.0.1.weight
# Unfrozen layer: features.6.9.block.0.1.bias
# Unfrozen layer: features.6.9.block.1.0.weight
# Unfrozen layer: features.6.9.block.1.1.weight
# Unfrozen layer: features.6.9.block.1.1.bias
# Unfrozen layer: features.6.9.block.2.fc1.weight
# Unfrozen layer: features.6.9.block.2.fc1.bias
# Unfrozen layer: features.6.9.block.2.fc2.weight
# Unfrozen layer: features.6.9.block.2.fc2.bias
# Unfrozen layer: features.6.9.block.3.0.weight
# Unfrozen layer: features.6.9.block.3.1.weight
# Unfrozen layer: features.6.9.block.3.1.bias
# Unfrozen layer: features.6.10.block.0.0.weight
# Unfrozen layer: features.6.10.block.0.1.weight
# Unfrozen layer: features.6.10.block.0.1.bias
# Unfrozen layer: features.6.10.block.1.0.weight
# Unfrozen layer: features.6.10.block.1.1.weight
# Unfrozen layer: features.6.10.block.1.1.bias
# Unfrozen layer: features.6.10.block.2.fc1.weight
# Unfrozen layer: features.6.10.block.2.fc1.bias
# Unfrozen layer: features.6.10.block.2.fc2.weight
# Unfrozen layer: features.6.10.block.2.fc2.bias
# Unfrozen layer: features.6.10.block.3.0.weight
# Unfrozen layer: features.6.10.block.3.1.weight
# Unfrozen layer: features.6.10.block.3.1.bias
# Unfrozen layer: features.7.0.block.0.0.weight
# Unfrozen layer: features.7.0.block.0.1.weight
# Unfrozen layer: features.7.0.block.0.1.bias
# Unfrozen layer: features.7.0.block.1.0.weight
# Unfrozen layer: features.7.0.block.1.1.weight
# Unfrozen layer: features.7.0.block.1.1.bias
# Unfrozen layer: features.7.0.block.2.fc1.weight
# Unfrozen layer: features.7.0.block.2.fc1.bias
# Unfrozen layer: features.7.0.block.2.fc2.weight
# Unfrozen layer: features.7.0.block.2.fc2.bias
# Unfrozen layer: features.7.0.block.3.0.weight
# Unfrozen layer: features.7.0.block.3.1.weight
# Unfrozen layer: features.7.0.block.3.1.bias
# Unfrozen layer: features.7.1.block.0.0.weight
# Unfrozen layer: features.7.1.block.0.1.weight
# Unfrozen layer: features.7.1.block.0.1.bias
# Unfrozen layer: features.7.1.block.1.0.weight
# Unfrozen layer: features.7.1.block.1.1.weight
# Unfrozen layer: features.7.1.block.1.1.bias
# Unfrozen layer: features.7.1.block.2.fc1.weight
# Unfrozen layer: features.7.1.block.2.fc1.bias
# Unfrozen layer: features.7.1.block.2.fc2.weight
# Unfrozen layer: features.7.1.block.2.fc2.bias
# Unfrozen layer: features.7.1.block.3.0.weight
# Unfrozen layer: features.7.1.block.3.1.weight
# Unfrozen layer: features.7.1.block.3.1.bias
# Unfrozen layer: features.7.2.block.0.0.weight
# Unfrozen layer: features.7.2.block.0.1.weight
# Unfrozen layer: features.7.2.block.0.1.bias
# Unfrozen layer: features.7.2.block.1.0.weight
# Unfrozen layer: features.7.2.block.1.1.weight
# Unfrozen layer: features.7.2.block.1.1.bias
# Unfrozen layer: features.7.2.block.2.fc1.weight
# Unfrozen layer: features.7.2.block.2.fc1.bias
# Unfrozen layer: features.7.2.block.2.fc2.weight
# Unfrozen layer: features.7.2.block.2.fc2.bias
# Unfrozen layer: features.7.2.block.3.0.weight
# Unfrozen layer: features.7.2.block.3.1.weight
# Unfrozen layer: features.7.2.block.3.1.bias
# Unfrozen layer: features.8.0.weight
# Unfrozen layer: features.8.1.weight
# Unfrozen layer: features.8.1.bias

# %%
summary(model=model1,
        input_size=(50, 3, 150, 150), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [50, 3, 150, 150]    [50, 4]              --                   Partial
# ├─Sequential (features)                                      [50, 3, 150, 150]    [50, 2304, 5, 5]     --                   Partial
# │    └─Conv2dNormActivation (0)                              [50, 3, 150, 150]    [50, 56, 75, 75]     --                   False
# │    │    └─Conv2d (0)                                       [50, 3, 150, 150]    [50, 56, 75, 75]     (1,512)              False
# │    │    └─BatchNorm2d (1)                                  [50, 56, 75, 75]     [50, 56, 75, 75]     (112)                False
# │    │    └─SiLU (2)                                         [50, 56, 75, 75]     [50, 56, 75, 75]     --                   --
# │    └─Sequential (1)                                        [50, 56, 75, 75]     [50, 32, 75, 75]     --                   False
# │    │    └─MBConv (0)                                       [50, 56, 75, 75]     [50, 32, 75, 75]     (4,110)              False
# │    │    └─MBConv (1)                                       [50, 32, 75, 75]     [50, 32, 75, 75]     (1,992)              False
# │    │    └─MBConv (2)                                       [50, 32, 75, 75]     [50, 32, 75, 75]     (1,992)              False
# │    └─Sequential (2)                                        [50, 32, 75, 75]     [50, 40, 38, 38]     --                   False
# │    │    └─MBConv (0)                                       [50, 32, 75, 75]     [50, 40, 38, 38]     (19,672)             False
# │    │    └─MBConv (1)                                       [50, 40, 38, 38]     [50, 40, 38, 38]     (27,450)             False
# │    │    └─MBConv (2)                                       [50, 40, 38, 38]     [50, 40, 38, 38]     (27,450)             False
# │    │    └─MBConv (3)                                       [50, 40, 38, 38]     [50, 40, 38, 38]     (27,450)             False
# │    │    └─MBConv (4)                                       [50, 40, 38, 38]     [50, 40, 38, 38]     (27,450)             False
# │    │    └─MBConv (5)                                       [50, 40, 38, 38]     [50, 40, 38, 38]     (27,450)             False
# │    └─Sequential (3)                                        [50, 40, 38, 38]     [50, 72, 19, 19]     --                   False
# │    │    └─MBConv (0)                                       [50, 40, 38, 38]     [50, 72, 19, 19]     (39,034)             False
# │    │    └─MBConv (1)                                       [50, 72, 19, 19]     [50, 72, 19, 19]     (90,882)             False
# │    │    └─MBConv (2)                                       [50, 72, 19, 19]     [50, 72, 19, 19]     (90,882)             False
# │    │    └─MBConv (3)                                       [50, 72, 19, 19]     [50, 72, 19, 19]     (90,882)             False
# │    │    └─MBConv (4)                                       [50, 72, 19, 19]     [50, 72, 19, 19]     (90,882)             False
# │    │    └─MBConv (5)                                       [50, 72, 19, 19]     [50, 72, 19, 19]     (90,882)             False
# │    └─Sequential (4)                                        [50, 72, 19, 19]     [50, 144, 10, 10]    --                   False
# │    │    └─MBConv (0)                                       [50, 72, 19, 19]     [50, 144, 10, 10]    (115,218)            False
# │    │    └─MBConv (1)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (2)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (3)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (4)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (5)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (6)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    │    └─MBConv (7)                                       [50, 144, 10, 10]    [50, 144, 10, 10]    (323,460)            False
# │    └─Sequential (5)                                        [50, 144, 10, 10]    [50, 200, 10, 10]    --                   True
# │    │    └─MBConv (0)                                       [50, 144, 10, 10]    [50, 200, 10, 10]    385,780              True
# │    │    └─MBConv (1)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (2)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (3)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (4)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (5)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (6)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    │    └─MBConv (7)                                       [50, 200, 10, 10]    [50, 200, 10, 10]    636,450              True
# │    └─Sequential (6)                                        [50, 200, 10, 10]    [50, 344, 5, 5]      --                   True
# │    │    └─MBConv (0)                                       [50, 200, 10, 10]    [50, 344, 5, 5]      809,538              True
# │    │    └─MBConv (1)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (2)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (3)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (4)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (5)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (6)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (7)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (8)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (9)                                       [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    │    └─MBConv (10)                                      [50, 344, 5, 5]      [50, 344, 5, 5]      1,837,734            True
# │    └─Sequential (7)                                        [50, 344, 5, 5]      [50, 576, 5, 5]      --                   True
# │    │    └─MBConv (0)                                       [50, 344, 5, 5]      [50, 576, 5, 5]      2,284,022            True
# │    │    └─MBConv (1)                                       [50, 576, 5, 5]      [50, 576, 5, 5]      5,026,320            True
# │    │    └─MBConv (2)                                       [50, 576, 5, 5]      [50, 576, 5, 5]      5,026,320            True
# │    └─Conv2dNormActivation (8)                              [50, 576, 5, 5]      [50, 2304, 5, 5]     --                   True
# │    │    └─Conv2d (0)                                       [50, 576, 5, 5]      [50, 2304, 5, 5]     1,327,104            True
# │    │    └─BatchNorm2d (1)                                  [50, 2304, 5, 5]     [50, 2304, 5, 5]     4,608                True
# │    │    └─SiLU (2)                                         [50, 2304, 5, 5]     [50, 2304, 5, 5]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [50, 2304, 5, 5]     [50, 2304, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [50, 2304]           [50, 4]              --                   True
# │    └─Dropout (0)                                           [50, 2304]           [50, 2304]           --                   --
# │    └─Linear (1)                                            [50, 2304]           [50, 4]              9,220                True
# ============================================================================================================================================
# Total params: 40,744,924
# Trainable params: 37,705,402
# Non-trainable params: 3,039,522
# Total mult-adds (G): 83.57
# ============================================================================================================================================
# Input size (MB): 13.50
# Forward/backward pass size (MB): 11389.87
# Params size (MB): 162.98
# Estimated Total Size (MB): 11566.35
# ============================================================================================================================================

# %%
rand_image_tensor = torch.randn(size=(3, 150, 150))
rand_image_tensor=rand_image_tensor.to(device)

# %%
# now trying to see the flatten shape
model1(rand_image_tensor.unsqueeze(0))
# Out:
# tensor([[-0.0028,  0.0008,  0.0475,  0.0737]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
# from torch.optim.lr_scheduler import ReduceLROnPlateau
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model1.parameters(),lr=0.001)


# scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

# scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[6,10,15], gamma=0.001)

# %%
def train_benchmark(start:float, end:float, device:torch.device = None):
    """
    start: is the start time of the training benchmark

    end: is the end time of the training benchmark

    device: is the device which is going to run the training benchmark either 'cpu' or 'gpu' in case of mac m1 'mps'
    """
    print(f" training benchmark on {device} took {(end-start):.3f} seconds")

# %%
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
train_loss_values=[]
train_acc_values= []

def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):



    # """Performs a training step with the model trying to learn on data_loader."""
  global train_loss_values
  global train_acc_values
  train_loss, train_acc = 0, 0

  # Put model into training mode
  model.train()

    # Add a loop to loop through the training batches
  for batch, (X, y) in enumerate(data_loader):
        # Put data on target device
      X, y = X.to(device), y.to(device)

        # 1. Forward pass (outputs the raw logits from the model)
      y_pred = model(X)

        # 2. Calculate loss and accuracy (per batch)
      loss = loss_fn(y_pred, y)
      train_loss += loss.item() # accumulate train loss
      train_acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1)) # go from logits -> prediction labels

        # 3. Optimizer zero grad
      optimizer.zero_grad()

        # 4. Loss backward
      loss.backward()

        # 5. Optimizer step (update the model's parameters once *per batch*)
      optimizer.step()
      # scheduler.step(train_loss)

    # Divide total train loss and acc by length of train dataloader
  train_loss /= len(data_loader)
  train_acc /= len(data_loader)
  train_loss_values.append(train_loss)
  train_acc_values.append(train_acc)
  print(f"Train loss: {train_loss:.5f} | Train acc: {train_acc:.2f}%")

# %%
validation_loss_values=[]
validation_acc_values=[]
def valid_step(model: torch.nn.Module,
              data_loader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):

    # """Performs a validation loop step on model going over data_loader."""

  global validation_loss_values
  global validation_acc_values
  valid_loss, valid_acc = 0, 0

    # Put the model in eval mode
  model.eval()

    # Turn on inference mode context manager
  with torch.inference_mode():

    for X, y in data_loader:

            # Send the data to the target device
      X, y = X.to(device), y.to(device)

            # 1. Forward pass (outputs raw logits)
      valid_pred = model(X)

            # 2. Calculate the loss and accuracy
      valid_loss += loss_fn(valid_pred, y)
      valid_acc += accuracy_fn(y_true=y, y_pred=valid_pred.argmax(dim=1))  # go from logits -> prediction labels

        # Adjust metrics and print out
    valid_loss /= len(data_loader)
    valid_acc /= len(data_loader)
    validation_loss_values.append(valid_loss)
    validation_acc_values.append(valid_acc)
    print(f"valid loss: {valid_loss:.5f} | valid acc: {valid_acc:.2f}%\n")

# %%
from timeit import default_timer as timer

start = timer()
EPOCHS= 30

for epoch in tqdm(range(EPOCHS)):
  print(f"Epoch: {epoch} \n......")

  train_step(model1,train_loader,loss_fn,optimizer,accuracy_fn,device)
  valid_step(model1,val_loader,loss_fn,accuracy_fn,device)



end =timer()
train_benchmark(start=start,end=end,device=str(next(model1.parameters()).device))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 0
# ......
# Train loss: 0.74604 | Train acc: 65.83%
# valid loss: 0.95088 | valid acc: 69.10%
#
# Epoch: 1
# ......
# Train loss: 0.49195 | Train acc: 79.23%
# valid loss: 0.83146 | valid acc: 69.74%
#
# Epoch: 2
# ......
# Train loss: 0.38076 | Train acc: 84.37%
# valid loss: 0.66490 | valid acc: 75.59%
#
# Epoch: 3
# ......
# Train loss: 0.29863 | Train acc: 88.24%
# valid loss: 0.44656 | valid acc: 84.59%
#
# Epoch: 4
# ......
# Train loss: 0.23156 | Train acc: 90.98%
# valid loss: 0.49649 | valid acc: 84.08%
#
# Epoch: 5
# ......
# Train loss: 0.19354 | Train acc: 92.86%
# valid loss: 0.27789 | valid acc: 89.90%
#
# Epoch: 6
# ......
# Train loss: 0.15245 | Train acc: 94.32%
# valid loss: 0.26510 | valid acc: 91.56%
#
# Epoch: 7
# ......
# Train loss: 0.12927 | Train acc: 95.44%
# valid loss: 0.18194 | valid acc: 94.08%
#
# Epoch: 8
# ......
# Train loss: 0.10823 | Train acc: 95.90%
# valid loss: 0.17234 | valid acc: 93.64%
#
# Epoch: 9
# ......
# Train loss: 0.10579 | Train acc: 96.18%
# valid loss: 0.17549 | valid acc: 94.28%
#
# Epoch: 10
# ......
# Train loss: 0.09475 | Train acc: 96.60%
# valid loss: 0.15605 | valid acc: 94.82%
#
# Epoch: 11
# ......
# Train loss: 0.08708 | Train acc: 96.81%
# valid loss: 0.15441 | valid acc: 95.13%
#
# Epoch: 12
# ......
# Train loss: 0.06844 | Train acc: 97.56%
# valid loss: 0.11154 | valid acc: 95.67%
#
# Epoch: 13
# ......
# Train loss: 0.06684 | Train acc: 97.80%
# valid loss: 0.14358 | valid acc: 95.23%
#
# Epoch: 14
# ......
# Train loss: 0.07153 | Train acc: 97.66%
# valid loss: 0.15053 | valid acc: 95.15%
#
# Epoch: 15
# ......
# Train loss: 0.05889 | Train acc: 97.92%
# valid loss: 0.14262 | valid acc: 95.95%
#
# Epoch: 16
# ......
# Train loss: 0.07653 | Train acc: 97.46%
# valid loss: 0.13692 | valid acc: 95.41%
#
# Epoch: 17
# ......
# Train loss: 0.05132 | Train acc: 98.23%
# valid loss: 0.13431 | valid acc: 96.26%
#
# Epoch: 18
# ......
# Train loss: 0.05392 | Train acc: 98.07%
# valid loss: 0.08967 | valid acc: 96.67%
#
# Epoch: 19
# ......
# Train loss: 0.05303 | Train acc: 98.01%
# valid loss: 0.14082 | valid acc: 95.72%
#
# Epoch: 20
# ......
# Train loss: 0.05724 | Train acc: 98.06%
# valid loss: 0.12197 | valid acc: 95.92%
#
# Epoch: 21
# ......
# Train loss: 0.06476 | Train acc: 97.92%
# valid loss: 0.17032 | valid acc: 95.13%
#
# Epoch: 22
# ......
# Train loss: 0.06458 | Train acc: 97.77%
# valid loss: 0.14773 | valid acc: 95.44%
#
# Epoch: 23
# ......
# Train loss: 0.04583 | Train acc: 98.42%
# valid loss: 0.12166 | valid acc: 96.08%
#
# Epoch: 24
# ......
# Train loss: 0.04521 | Train acc: 98.43%
# valid loss: 0.13553 | valid acc: 96.05%
#
# Epoch: 25
# ......
# Train loss: 0.04054 | Train acc: 98.72%
# valid loss: 0.09013 | valid acc: 97.36%
#
# Epoch: 26
# ......
# Train loss: 0.04114 | Train acc: 98.56%
# valid loss: 0.12147 | valid acc: 96.26%
#
# Epoch: 27
# ......
# Train loss: 0.03363 | Train acc: 98.86%
# valid loss: 0.13424 | valid acc: 96.10%
#
# Epoch: 28
# ......
# Train loss: 0.04386 | Train acc: 98.38%
# valid loss: 0.08671 | valid acc: 96.97%
#
# Epoch: 29
# ......
# Train loss: 0.05449 | Train acc: 98.21%
# valid loss: 0.12173 | valid acc: 95.67%
#
#  training benchmark on cuda:0 took 1443.523 seconds

# %%
# let's plot the train and test loss functions
len(train_acc_values)
epochs = list(range(0,len(train_loss_values)))

# Plot the losses
plt.plot(epochs, torch.tensor(train_loss_values).cpu(), label='Training Loss')
plt.plot(epochs, torch.tensor(validation_loss_values).cpu(), label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# accuracylen(train_acc_values)
epochs = list(range(0,len(train_acc_values)))

# Plot the losses
plt.plot(epochs, torch.tensor(train_acc_values).cpu(), label='Training accuracy')
plt.plot(epochs, torch.tensor(validation_acc_values).cpu(), label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
def make_predictions(model: torch.nn.Module,
                     data: list,
                     device: torch.device = device):
  pred_probs = []
  model.to(device)
  model.eval()
  with torch.inference_mode():
    for sample in data:
      # Prepare the sample (add a batch dimension and pass to target device)
      sample = torch.unsqueeze(sample, dim=0).to(device)

      # Forward pass (model outputs raw logits)
      pred_logit = model(sample)

      # Get prediction probability (logit -> prediction probability)
      pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)

      # Get pred_prob off the GPU for further calculations
      pred_probs.append(pred_prob.cpu())

  # Stack the pred_probs to turn list into a tensor
  return torch.stack(pred_probs)

# %%
import random
# random.seed(42)
print(len(test_dataset))
test_samples = []
test_labels = []
for sample, label in random.sample(list(test_dataset), k=1920):
  test_samples.append(sample)
  test_labels.append(label)

# View the first sample shape
test_samples[0].shape
# Out:
# 1920
# torch.Size([3, 150, 150])

# %%
pred_probs = make_predictions(model=model1,
                              data=test_samples)

# View first two prediction probabilities
pred_probs[:2]
# Out:
# tensor([[2.8287e-02, 6.2767e-07, 9.7057e-01, 1.1431e-03],
#         [1.0000e+00, 2.1389e-16, 2.4666e-11, 1.2481e-06]])

# %%
pred_classes = pred_probs.argmax(dim=1)
pred_classes
# Out:
# tensor([2, 0, 2,  ..., 0, 2, 3])

# %%
array_test_labels =[]

for item in test_labels:

  array_test_labels.append(item.item())

# array_test_labels

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
comparison= {
    'predicted_labels':pred_classes,
    'true labels':array_test_labels
}

import pandas as pd

df= pd.DataFrame(data=comparison)

df.head(50)

accuracy_score(test_labels,pred_classes)*100
# Out:
# 95.67708333333333

# %%
df.head(20)
# Out:
#     predicted_labels  true labels
# 0                  2            2
# 1                  0            0
# 2                  2            2
# 3                  2            3
# 4                  2            0
# 5                  0            0
# 6                  1            1
# 7                  1            1
# 8                  1            1
# 9                  3            0
# 10                 3            3
# 11                 0            0
# 12                 2            0
# 13                 3            3
# 14                 0            0
# 15                 1            1
# 16                 2            2
# 17                 0            0
# 18                 3            3
# 19                 2            2

# %%
cm = confusion_matrix(pred_classes,array_test_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(8,8))
disp.plot(ax=ax)
print(classification_report(pred_classes,array_test_labels))
print(class_idx)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       445
#            1       1.00      1.00      1.00       493
#            2       0.97      0.90      0.93       521
#            3       0.91      0.94      0.93       461
#
#     accuracy                           0.96      1920
#    macro avg       0.96      0.96      0.96      1920
# weighted avg       0.96      0.96      0.96      1920
#
# {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}

# %%
# Create model dictory path
MODEL_PATH = Path(f"{path}/models")
MODEL_PATH.mkdir(parents=True,
                 exist_ok=True)

# Create model save
MODEL_NAME = "SMOTE MRI Predictor 16.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model1.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: None/models/SMOTE MRI Predictor 16.pth
