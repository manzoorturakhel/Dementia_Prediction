# %% [markdown]
# <a href="https://colab.research.google.com/github/manzoorturakhel/Dementia_Prediction/blob/main/densenet_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
path=drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile as zf
files = zf.ZipFile("/content/drive/MyDrive/dataset.zip", 'r')
files.extractall('')
files.close()

# %%
# importing important libraries

import torch
from torch import nn

import torchvision
from torchvision import transforms,datasets, models
from torchvision.transforms import ToTensor, v2

from torch.utils.data import DataLoader, random_split, Dataset

from imblearn.over_sampling import SMOTE




import matplotlib.pyplot  as plt

from tqdm.auto import tqdm

import os

from pathlib import Path

# %%
# checking if gpu is available

if torch.cuda.is_available():
    device = "cuda" # NVIDIA GPU
# elif torch.backends.mps.is_available():
#     device = "mps" # Apple GPU
else:
    device = "cpu" # Defaults to CPU if NVIDIA GPU/Apple GPU aren't available

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# lets prepare our data for training and testing and do some EDA
import numpy as np
from imblearn.over_sampling import SMOTE
from torch.utils.data import TensorDataset, DataLoader
import torch
root_dir= "Alzheimer_s Dataset"
train_dir = os.path.join(root_dir,'train')

simple_transform = v2.Compose([
    v2.Grayscale(num_output_channels=1),
    v2.ToTensor(),
])

transform = v2.Compose([


        v2.ColorJitter(brightness=0.5),  # Brightness adjustment


        v2.RandomAffine(degrees=0, scale=(0.98, 1.2)), # Zooming


        v2.Pad(padding=5, fill=0),  # Filling (padding with zeros)

    v2.RandomHorizontalFlip(p=0.4),  # Flipping
    v2.RandomAdjustSharpness(sharpness_factor=2,p=0.5),
    v2.Resize((160, 160)),  # Rescaling
    v2.CenterCrop(size=(150,150)),
    # v2.Grayscale(num_output_channels=1),
    v2.ToTensor(),



])
simple_train_data =  datasets.ImageFolder(train_dir,transform=simple_transform)
# now that we have sat the train and test directories we will prepare it to make it as a dataset using datasets.ImageFolder
train_data = datasets.ImageFolder(train_dir,transform=transform)

train_size = int(0.7 * len(train_data))
val_size = int(0.15 * len(train_data))
test_size = len(train_data) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(train_data, [train_size, val_size, test_size])





# let check the data now
print(len(train_data.samples)) #

class_names = train_data.classes
class_idx = train_data.class_to_idx


batch_size = 50

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 6400
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
 root_dir= "Alzheimer_s Dataset"
 for dirpath, dirnames, filenames in os.walk(root_dir):
  print(f" directory name:{dirnames} files lens:{len(filenames)}")
# Out:
#  directory name:['train'] files lens:1
#  directory name:['MildDemented', 'NonDemented', 'ModerateDemented', 'VeryMildDemented'] files lens:1
#  directory name:[] files lens:896
#  directory name:[] files lens:3200
#  directory name:[] files lens:64
#  directory name:[] files lens:2240

# %%
# befor applying SMOTE imbalance classes
MildDemented = os.path.join(train_dir,'MildDemented')
ModerateDemented= os.path.join(train_dir,'ModerateDemented')
VeryMildDemented=os.path.join(train_dir,'VeryMildDemented')
NonDemented=os.path.join(train_dir,'NonDemented')


num_of_classes_in_training =  {
    'MildD':len(os.listdir(MildDemented)),
    'ModerateD':len(os.listdir(ModerateDemented)),
    'VeryMildD':len(os.listdir(VeryMildDemented)),
    'NonD':len(os.listdir(NonDemented))
}
print(num_of_classes_in_training)
plt.bar(num_of_classes_in_training.keys(),num_of_classes_in_training.values(),color=['black','red','green','blue']);
plt.title('class numbers');
# Out:
# {'MildD': 896, 'ModerateD': 64, 'VeryMildD': 2240, 'NonD': 3200}

# %%
print(len(train_loader.dataset))
print(type(train_data.classes))
# Out:
# 4480
# <class 'list'>

# %%
# applying SMOTE to balance classes and see whether it improves the performance

X = []
y = []
for img, label in train_data:
    X.append(img.numpy().flatten())  # Flatten the image
    y.append(label)

X = np.array(X)
y = np.array(y)

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Convert back to PyTorch tensors
X_resampled = torch.from_numpy(X_resampled).float().view(-1, 3, 150, 150)  # Reshape back to image format
y_resampled = torch.from_numpy(y_resampled).long()

# Create a new TensorDataset
balanced_dataset = TensorDataset(X_resampled, y_resampled)




class TransformedTensorDataset(Dataset):
    def __init__(self, tensor_dataset, transform=None):
        self.tensor_dataset = tensor_dataset
        self.transform = transform

    def __getitem__(self, index):
        img, label = self.tensor_dataset[index]

        # Convert tensor to PIL Image for transforms
        img = transforms.ToPILImage()(img)

        if self.transform:
            img = self.transform(img)

        return img, label

    def __len__(self):
        return len(self.tensor_dataset)

# # Create the transformed dataset
transformed_balanced_dataset = TransformedTensorDataset(balanced_dataset, transform=transform)

# print(len(transformed_balanced_dataset))

# %%
print(type(balanced_dataset.tensors),type(train_data.imgs))
# Out:
# <class 'tuple'> <class 'list'>

# %%
print(len(transformed_balanced_dataset))

# splitting the new data between train,validation and test


train_size = int(0.7 * len(transformed_balanced_dataset))
val_size = int(0.15 * len(transformed_balanced_dataset))
test_size = len(transformed_balanced_dataset) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(transformed_balanced_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)





# let check the data now
print(len(transformed_balanced_dataset.tensor_dataset))

class_names = train_data.classes
class_idx = train_data.class_to_idx
# Out:
# 12800
# 12800

# %%
# after applying smote


unique, counts = np.unique(y_resampled, return_counts=True)

unique,counts
# new number of sample per class object
new_number_of_classes={}


for i in range(len(unique)):
  new_number_of_classes[class_names[i]] = counts[i]


new_number_of_classes

# Plot the bar graph
plt.figure(figsize=(10, 5))
plt.bar(new_number_of_classes.keys(), new_number_of_classes.values(), color=['red','black','green','blue'])
plt.xlabel('Class')
plt.ylabel('Number of samples')
plt.title('Number of Samples per Class after SMOTE')
plt.show()

# %%
print(type(train_data.imgs))
# Out:
# <class 'list'>

# %%
# let visualize images after and before data augmentation

plt.figure(figsize=(7,6))

image,label  = simple_train_data[5]

# augmented data
image1,label1 = train_data[5]

print(image.shape)

plt.subplot(1,2,1)
plt.imshow(image.permute(1, 2, 0),cmap='gray');
plt.title(f" before prep:{class_names[label]}")
plt.axis(False)
plt.subplot(1,2,2)
plt.imshow(image1.permute(1, 2, 0),cmap='gray');
plt.title(f" after prep:{class_names[label1]}")
plt.axis(False)
# Out:
# torch.Size([1, 208, 176])
# (-0.5, 149.5, 149.5, -0.5)

# %%
# let visualize some random images from the dataset
def displayRandomImage(data,nrows:int=4,ncols:int=4):
  """
  data will be from train1 and train2 to see the difference
  nrows are number of rows and by default it will be 4 unless specified
  ncols are number of cols and by default it will be 4 unless specified
  """
  plt.figure(figsize=(9,9))
  torch.manual_seed(42)

  for i in range(1,nrows*ncols+1):

    random_idx = torch.randint(0,len(data),size=[1]).item()
    image,label = data[random_idx]
    plt.subplot(nrows,ncols,i)
    plt.imshow(image.permute(1, 2, 0),cmap='gray');
    plt.title(class_names[label]);
    plt.axis(False);

# %%
print("images before preprocessing.....\n")

displayRandomImage(simple_train_data)
# Out:
# images before preprocessing.....

# %%
print("images after preprocessing.....\n")

displayRandomImage(train_data)
# Out:
# images after preprocessing.....

# %%
# pip install torchsampler
weights = torchvision.models.DenseNet121_Weights.DEFAULT    # .DEFAULT = best available weights
model1 = torchvision.models.densenet121(weights=weights).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 106MB/s]

# %%
try:
  import torchinfo
except:
  # !pip install torchinfo
  import torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
# model1 = customCNN(input_shape=1,filters=32,output_shape=4).to(device)
from torchinfo import summary
# this is how the architecture of the models looks like before finetuning 
summary(model=model1,
        input_size=(50, 3, 150, 150), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [50, 3, 150, 150]    [50, 1000]           --                   True
# ├─Sequential (features)                       [50, 3, 150, 150]    [50, 1024, 4, 4]     --                   True
# │    └─Conv2d (conv0)                         [50, 3, 150, 150]    [50, 64, 75, 75]     9,408                True
# │    └─BatchNorm2d (norm0)                    [50, 64, 75, 75]     [50, 64, 75, 75]     128                  True
# │    └─ReLU (relu0)                           [50, 64, 75, 75]     [50, 64, 75, 75]     --                   --
# │    └─MaxPool2d (pool0)                      [50, 64, 75, 75]     [50, 64, 38, 38]     --                   --
# │    └─_DenseBlock (denseblock1)              [50, 64, 38, 38]     [50, 256, 38, 38]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 64, 38, 38]     [50, 32, 38, 38]     45,440               True
# │    │    └─_DenseLayer (denselayer2)         [50, 64, 38, 38]     [50, 32, 38, 38]     49,600               True
# │    │    └─_DenseLayer (denselayer3)         [50, 64, 38, 38]     [50, 32, 38, 38]     53,760               True
# │    │    └─_DenseLayer (denselayer4)         [50, 64, 38, 38]     [50, 32, 38, 38]     57,920               True
# │    │    └─_DenseLayer (denselayer5)         [50, 64, 38, 38]     [50, 32, 38, 38]     62,080               True
# │    │    └─_DenseLayer (denselayer6)         [50, 64, 38, 38]     [50, 32, 38, 38]     66,240               True
# │    └─_Transition (transition1)              [50, 256, 38, 38]    [50, 128, 19, 19]    --                   True
# │    │    └─BatchNorm2d (norm)                [50, 256, 38, 38]    [50, 256, 38, 38]    512                  True
# │    │    └─ReLU (relu)                       [50, 256, 38, 38]    [50, 256, 38, 38]    --                   --
# │    │    └─Conv2d (conv)                     [50, 256, 38, 38]    [50, 128, 38, 38]    32,768               True
# │    │    └─AvgPool2d (pool)                  [50, 128, 38, 38]    [50, 128, 19, 19]    --                   --
# │    └─_DenseBlock (denseblock2)              [50, 128, 19, 19]    [50, 512, 19, 19]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 128, 19, 19]    [50, 32, 19, 19]     53,760               True
# │    │    └─_DenseLayer (denselayer2)         [50, 128, 19, 19]    [50, 32, 19, 19]     57,920               True
# │    │    └─_DenseLayer (denselayer3)         [50, 128, 19, 19]    [50, 32, 19, 19]     62,080               True
# │    │    └─_DenseLayer (denselayer4)         [50, 128, 19, 19]    [50, 32, 19, 19]     66,240               True
# │    │    └─_DenseLayer (denselayer5)         [50, 128, 19, 19]    [50, 32, 19, 19]     70,400               True
# │    │    └─_DenseLayer (denselayer6)         [50, 128, 19, 19]    [50, 32, 19, 19]     74,560               True
# │    │    └─_DenseLayer (denselayer7)         [50, 128, 19, 19]    [50, 32, 19, 19]     78,720               True
# │    │    └─_DenseLayer (denselayer8)         [50, 128, 19, 19]    [50, 32, 19, 19]     82,880               True
# │    │    └─_DenseLayer (denselayer9)         [50, 128, 19, 19]    [50, 32, 19, 19]     87,040               True
# │    │    └─_DenseLayer (denselayer10)        [50, 128, 19, 19]    [50, 32, 19, 19]     91,200               True
# │    │    └─_DenseLayer (denselayer11)        [50, 128, 19, 19]    [50, 32, 19, 19]     95,360               True
# │    │    └─_DenseLayer (denselayer12)        [50, 128, 19, 19]    [50, 32, 19, 19]     99,520               True
# │    └─_Transition (transition2)              [50, 512, 19, 19]    [50, 256, 9, 9]      --                   True
# │    │    └─BatchNorm2d (norm)                [50, 512, 19, 19]    [50, 512, 19, 19]    1,024                True
# │    │    └─ReLU (relu)                       [50, 512, 19, 19]    [50, 512, 19, 19]    --                   --
# │    │    └─Conv2d (conv)                     [50, 512, 19, 19]    [50, 256, 19, 19]    131,072              True
# │    │    └─AvgPool2d (pool)                  [50, 256, 19, 19]    [50, 256, 9, 9]      --                   --
# │    └─_DenseBlock (denseblock3)              [50, 256, 9, 9]      [50, 1024, 9, 9]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 256, 9, 9]      [50, 32, 9, 9]       70,400               True
# │    │    └─_DenseLayer (denselayer2)         [50, 256, 9, 9]      [50, 32, 9, 9]       74,560               True
# │    │    └─_DenseLayer (denselayer3)         [50, 256, 9, 9]      [50, 32, 9, 9]       78,720               True
# │    │    └─_DenseLayer (denselayer4)         [50, 256, 9, 9]      [50, 32, 9, 9]       82,880               True
# │    │    └─_DenseLayer (denselayer5)         [50, 256, 9, 9]      [50, 32, 9, 9]       87,040               True
# │    │    └─_DenseLayer (denselayer6)         [50, 256, 9, 9]      [50, 32, 9, 9]       91,200               True
# │    │    └─_DenseLayer (denselayer7)         [50, 256, 9, 9]      [50, 32, 9, 9]       95,360               True
# │    │    └─_DenseLayer (denselayer8)         [50, 256, 9, 9]      [50, 32, 9, 9]       99,520               True
# │    │    └─_DenseLayer (denselayer9)         [50, 256, 9, 9]      [50, 32, 9, 9]       103,680              True
# │    │    └─_DenseLayer (denselayer10)        [50, 256, 9, 9]      [50, 32, 9, 9]       107,840              True
# │    │    └─_DenseLayer (denselayer11)        [50, 256, 9, 9]      [50, 32, 9, 9]       112,000              True
# │    │    └─_DenseLayer (denselayer12)        [50, 256, 9, 9]      [50, 32, 9, 9]       116,160              True
# │    │    └─_DenseLayer (denselayer13)        [50, 256, 9, 9]      [50, 32, 9, 9]       120,320              True
# │    │    └─_DenseLayer (denselayer14)        [50, 256, 9, 9]      [50, 32, 9, 9]       124,480              True
# │    │    └─_DenseLayer (denselayer15)        [50, 256, 9, 9]      [50, 32, 9, 9]       128,640              True
# │    │    └─_DenseLayer (denselayer16)        [50, 256, 9, 9]      [50, 32, 9, 9]       132,800              True
# │    │    └─_DenseLayer (denselayer17)        [50, 256, 9, 9]      [50, 32, 9, 9]       136,960              True
# │    │    └─_DenseLayer (denselayer18)        [50, 256, 9, 9]      [50, 32, 9, 9]       141,120              True
# │    │    └─_DenseLayer (denselayer19)        [50, 256, 9, 9]      [50, 32, 9, 9]       145,280              True
# │    │    └─_DenseLayer (denselayer20)        [50, 256, 9, 9]      [50, 32, 9, 9]       149,440              True
# │    │    └─_DenseLayer (denselayer21)        [50, 256, 9, 9]      [50, 32, 9, 9]       153,600              True
# │    │    └─_DenseLayer (denselayer22)        [50, 256, 9, 9]      [50, 32, 9, 9]       157,760              True
# │    │    └─_DenseLayer (denselayer23)        [50, 256, 9, 9]      [50, 32, 9, 9]       161,920              True
# │    │    └─_DenseLayer (denselayer24)        [50, 256, 9, 9]      [50, 32, 9, 9]       166,080              True
# │    └─_Transition (transition3)              [50, 1024, 9, 9]     [50, 512, 4, 4]      --                   True
# │    │    └─BatchNorm2d (norm)                [50, 1024, 9, 9]     [50, 1024, 9, 9]     2,048                True
# │    │    └─ReLU (relu)                       [50, 1024, 9, 9]     [50, 1024, 9, 9]     --                   --
# │    │    └─Conv2d (conv)                     [50, 1024, 9, 9]     [50, 512, 9, 9]      524,288              True
# │    │    └─AvgPool2d (pool)                  [50, 512, 9, 9]      [50, 512, 4, 4]      --                   --
# │    └─_DenseBlock (denseblock4)              [50, 512, 4, 4]      [50, 1024, 4, 4]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 512, 4, 4]      [50, 32, 4, 4]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [50, 512, 4, 4]      [50, 32, 4, 4]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [50, 512, 4, 4]      [50, 32, 4, 4]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [50, 512, 4, 4]      [50, 32, 4, 4]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [50, 512, 4, 4]      [50, 32, 4, 4]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [50, 512, 4, 4]      [50, 32, 4, 4]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [50, 512, 4, 4]      [50, 32, 4, 4]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [50, 512, 4, 4]      [50, 32, 4, 4]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [50, 512, 4, 4]      [50, 32, 4, 4]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [50, 512, 4, 4]      [50, 32, 4, 4]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [50, 512, 4, 4]      [50, 32, 4, 4]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [50, 512, 4, 4]      [50, 32, 4, 4]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [50, 512, 4, 4]      [50, 32, 4, 4]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [50, 512, 4, 4]      [50, 32, 4, 4]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [50, 512, 4, 4]      [50, 32, 4, 4]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [50, 512, 4, 4]      [50, 32, 4, 4]       166,080              True
# │    └─BatchNorm2d (norm5)                    [50, 1024, 4, 4]     [50, 1024, 4, 4]     2,048                True
# ├─Linear (classifier)                         [50, 1024]           [50, 1000]           1,025,000            True
# =============================================================================================================================
# Total params: 7,978,856
# Trainable params: 7,978,856
# Non-trainable params: 0
# Total mult-adds (G): 62.97
# =============================================================================================================================
# Input size (MB): 13.50
# Forward/backward pass size (MB): 4016.04
# Params size (MB): 31.92
# Estimated Total Size (MB): 4061.46
# =============================================================================================================================

# %% [markdown]
# Fine-tuning Process
#
#
# • intially by freezing all the layers to keep all the pretrained weights
#
#
# • unfreezing the last few layers which are trained on the new dataset

# %%
# fine-tuning the model by making all the layer freezed
for param in model1.parameters():
    param.requires_grad = False



# fine-tuning the last 5 layers for our specific problem
for layer in [model1.features[7],model1.features[8],model1.features[9],model1.features[10],model1.features[11]]:
    for param in layer.parameters():
        param.requires_grad = True

# Verifying
for name, param in model1.named_parameters():
    if param.requires_grad:
        print(f"Unfrozen layer: {name}")
# modification done to the fully connected layers
model1.classifier = torch.nn.Sequential(
    nn.Linear(in_features=1024, out_features=512, bias=True),
    nn.ReLU(inplace=True),
   nn.Linear(in_features=512, out_features=4, bias=True),



    ).to(device)
# Out:
# Unfrozen layer: features.transition2.norm.weight
# Unfrozen layer: features.transition2.norm.bias
# Unfrozen layer: features.transition2.conv.weight
# Unfrozen layer: features.denseblock3.denselayer1.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer1.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer1.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer1.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer1.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer1.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer2.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer2.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer2.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer2.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer2.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer2.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer3.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer3.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer3.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer3.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer3.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer3.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer4.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer4.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer4.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer4.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer4.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer4.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer5.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer5.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer5.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer5.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer5.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer5.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer6.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer6.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer6.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer6.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer6.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer6.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer7.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer7.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer7.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer7.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer7.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer7.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer8.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer8.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer8.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer8.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer8.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer8.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer9.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer9.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer9.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer9.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer9.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer9.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer10.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer10.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer10.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer10.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer10.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer10.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer11.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer11.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer11.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer11.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer11.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer11.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer12.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer12.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer12.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer12.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer12.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer12.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer13.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer13.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer13.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer13.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer13.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer13.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer14.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer14.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer14.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer14.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer14.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer14.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer15.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer15.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer15.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer15.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer15.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer15.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer16.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer16.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer16.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer16.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer16.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer16.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer17.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer17.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer17.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer17.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer17.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer17.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer18.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer18.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer18.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer18.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer18.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer18.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer19.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer19.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer19.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer19.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer19.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer19.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer20.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer20.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer20.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer20.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer20.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer20.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer21.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer21.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer21.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer21.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer21.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer21.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer22.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer22.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer22.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer22.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer22.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer22.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer23.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer23.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer23.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer23.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer23.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer23.conv2.weight
# Unfrozen layer: features.denseblock3.denselayer24.norm1.weight
# Unfrozen layer: features.denseblock3.denselayer24.norm1.bias
# Unfrozen layer: features.denseblock3.denselayer24.conv1.weight
# Unfrozen layer: features.denseblock3.denselayer24.norm2.weight
# Unfrozen layer: features.denseblock3.denselayer24.norm2.bias
# Unfrozen layer: features.denseblock3.denselayer24.conv2.weight
# Unfrozen layer: features.transition3.norm.weight
# Unfrozen layer: features.transition3.norm.bias
# Unfrozen layer: features.transition3.conv.weight
# Unfrozen layer: features.denseblock4.denselayer1.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer1.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer1.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer1.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer1.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer1.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer2.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer2.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer2.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer2.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer2.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer2.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer3.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer3.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer3.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer3.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer3.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer3.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer4.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer4.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer4.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer4.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer4.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer4.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer5.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer5.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer5.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer5.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer5.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer5.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer6.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer6.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer6.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer6.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer6.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer6.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer7.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer7.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer7.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer7.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer7.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer7.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer8.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer8.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer8.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer8.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer8.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer8.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer9.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer9.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer9.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer9.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer9.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer9.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer10.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer10.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer10.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer10.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer10.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer10.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer11.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer11.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer11.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer11.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer11.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer11.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer12.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer12.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer12.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer12.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer12.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer12.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer13.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer13.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer13.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer13.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer13.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer13.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer14.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer14.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer14.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer14.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer14.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer14.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer15.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer15.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer15.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer15.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer15.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer15.conv2.weight
# Unfrozen layer: features.denseblock4.denselayer16.norm1.weight
# Unfrozen layer: features.denseblock4.denselayer16.norm1.bias
# Unfrozen layer: features.denseblock4.denselayer16.conv1.weight
# Unfrozen layer: features.denseblock4.denselayer16.norm2.weight
# Unfrozen layer: features.denseblock4.denselayer16.norm2.bias
# Unfrozen layer: features.denseblock4.denselayer16.conv2.weight
# Unfrozen layer: features.norm5.weight
# Unfrozen layer: features.norm5.bias

# %%
# after fine-tuning the Trainable be seen as partial because the last layers are fine-tuned for this problem
summary(model=model1,
        input_size=(50, 3, 150, 150), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [50, 3, 150, 150]    [50, 4]              --                   Partial
# ├─Sequential (features)                       [50, 3, 150, 150]    [50, 1024, 4, 4]     --                   Partial
# │    └─Conv2d (conv0)                         [50, 3, 150, 150]    [50, 64, 75, 75]     (9,408)              False
# │    └─BatchNorm2d (norm0)                    [50, 64, 75, 75]     [50, 64, 75, 75]     (128)                False
# │    └─ReLU (relu0)                           [50, 64, 75, 75]     [50, 64, 75, 75]     --                   --
# │    └─MaxPool2d (pool0)                      [50, 64, 75, 75]     [50, 64, 38, 38]     --                   --
# │    └─_DenseBlock (denseblock1)              [50, 64, 38, 38]     [50, 256, 38, 38]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [50, 64, 38, 38]     [50, 32, 38, 38]     (45,440)             False
# │    │    └─_DenseLayer (denselayer2)         [50, 64, 38, 38]     [50, 32, 38, 38]     (49,600)             False
# │    │    └─_DenseLayer (denselayer3)         [50, 64, 38, 38]     [50, 32, 38, 38]     (53,760)             False
# │    │    └─_DenseLayer (denselayer4)         [50, 64, 38, 38]     [50, 32, 38, 38]     (57,920)             False
# │    │    └─_DenseLayer (denselayer5)         [50, 64, 38, 38]     [50, 32, 38, 38]     (62,080)             False
# │    │    └─_DenseLayer (denselayer6)         [50, 64, 38, 38]     [50, 32, 38, 38]     (66,240)             False
# │    └─_Transition (transition1)              [50, 256, 38, 38]    [50, 128, 19, 19]    --                   False
# │    │    └─BatchNorm2d (norm)                [50, 256, 38, 38]    [50, 256, 38, 38]    (512)                False
# │    │    └─ReLU (relu)                       [50, 256, 38, 38]    [50, 256, 38, 38]    --                   --
# │    │    └─Conv2d (conv)                     [50, 256, 38, 38]    [50, 128, 38, 38]    (32,768)             False
# │    │    └─AvgPool2d (pool)                  [50, 128, 38, 38]    [50, 128, 19, 19]    --                   --
# │    └─_DenseBlock (denseblock2)              [50, 128, 19, 19]    [50, 512, 19, 19]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [50, 128, 19, 19]    [50, 32, 19, 19]     (53,760)             False
# │    │    └─_DenseLayer (denselayer2)         [50, 128, 19, 19]    [50, 32, 19, 19]     (57,920)             False
# │    │    └─_DenseLayer (denselayer3)         [50, 128, 19, 19]    [50, 32, 19, 19]     (62,080)             False
# │    │    └─_DenseLayer (denselayer4)         [50, 128, 19, 19]    [50, 32, 19, 19]     (66,240)             False
# │    │    └─_DenseLayer (denselayer5)         [50, 128, 19, 19]    [50, 32, 19, 19]     (70,400)             False
# │    │    └─_DenseLayer (denselayer6)         [50, 128, 19, 19]    [50, 32, 19, 19]     (74,560)             False
# │    │    └─_DenseLayer (denselayer7)         [50, 128, 19, 19]    [50, 32, 19, 19]     (78,720)             False
# │    │    └─_DenseLayer (denselayer8)         [50, 128, 19, 19]    [50, 32, 19, 19]     (82,880)             False
# │    │    └─_DenseLayer (denselayer9)         [50, 128, 19, 19]    [50, 32, 19, 19]     (87,040)             False
# │    │    └─_DenseLayer (denselayer10)        [50, 128, 19, 19]    [50, 32, 19, 19]     (91,200)             False
# │    │    └─_DenseLayer (denselayer11)        [50, 128, 19, 19]    [50, 32, 19, 19]     (95,360)             False
# │    │    └─_DenseLayer (denselayer12)        [50, 128, 19, 19]    [50, 32, 19, 19]     (99,520)             False
# │    └─_Transition (transition2)              [50, 512, 19, 19]    [50, 256, 9, 9]      --                   True
# │    │    └─BatchNorm2d (norm)                [50, 512, 19, 19]    [50, 512, 19, 19]    1,024                True
# │    │    └─ReLU (relu)                       [50, 512, 19, 19]    [50, 512, 19, 19]    --                   --
# │    │    └─Conv2d (conv)                     [50, 512, 19, 19]    [50, 256, 19, 19]    131,072              True
# │    │    └─AvgPool2d (pool)                  [50, 256, 19, 19]    [50, 256, 9, 9]      --                   --
# │    └─_DenseBlock (denseblock3)              [50, 256, 9, 9]      [50, 1024, 9, 9]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 256, 9, 9]      [50, 32, 9, 9]       70,400               True
# │    │    └─_DenseLayer (denselayer2)         [50, 256, 9, 9]      [50, 32, 9, 9]       74,560               True
# │    │    └─_DenseLayer (denselayer3)         [50, 256, 9, 9]      [50, 32, 9, 9]       78,720               True
# │    │    └─_DenseLayer (denselayer4)         [50, 256, 9, 9]      [50, 32, 9, 9]       82,880               True
# │    │    └─_DenseLayer (denselayer5)         [50, 256, 9, 9]      [50, 32, 9, 9]       87,040               True
# │    │    └─_DenseLayer (denselayer6)         [50, 256, 9, 9]      [50, 32, 9, 9]       91,200               True
# │    │    └─_DenseLayer (denselayer7)         [50, 256, 9, 9]      [50, 32, 9, 9]       95,360               True
# │    │    └─_DenseLayer (denselayer8)         [50, 256, 9, 9]      [50, 32, 9, 9]       99,520               True
# │    │    └─_DenseLayer (denselayer9)         [50, 256, 9, 9]      [50, 32, 9, 9]       103,680              True
# │    │    └─_DenseLayer (denselayer10)        [50, 256, 9, 9]      [50, 32, 9, 9]       107,840              True
# │    │    └─_DenseLayer (denselayer11)        [50, 256, 9, 9]      [50, 32, 9, 9]       112,000              True
# │    │    └─_DenseLayer (denselayer12)        [50, 256, 9, 9]      [50, 32, 9, 9]       116,160              True
# │    │    └─_DenseLayer (denselayer13)        [50, 256, 9, 9]      [50, 32, 9, 9]       120,320              True
# │    │    └─_DenseLayer (denselayer14)        [50, 256, 9, 9]      [50, 32, 9, 9]       124,480              True
# │    │    └─_DenseLayer (denselayer15)        [50, 256, 9, 9]      [50, 32, 9, 9]       128,640              True
# │    │    └─_DenseLayer (denselayer16)        [50, 256, 9, 9]      [50, 32, 9, 9]       132,800              True
# │    │    └─_DenseLayer (denselayer17)        [50, 256, 9, 9]      [50, 32, 9, 9]       136,960              True
# │    │    └─_DenseLayer (denselayer18)        [50, 256, 9, 9]      [50, 32, 9, 9]       141,120              True
# │    │    └─_DenseLayer (denselayer19)        [50, 256, 9, 9]      [50, 32, 9, 9]       145,280              True
# │    │    └─_DenseLayer (denselayer20)        [50, 256, 9, 9]      [50, 32, 9, 9]       149,440              True
# │    │    └─_DenseLayer (denselayer21)        [50, 256, 9, 9]      [50, 32, 9, 9]       153,600              True
# │    │    └─_DenseLayer (denselayer22)        [50, 256, 9, 9]      [50, 32, 9, 9]       157,760              True
# │    │    └─_DenseLayer (denselayer23)        [50, 256, 9, 9]      [50, 32, 9, 9]       161,920              True
# │    │    └─_DenseLayer (denselayer24)        [50, 256, 9, 9]      [50, 32, 9, 9]       166,080              True
# │    └─_Transition (transition3)              [50, 1024, 9, 9]     [50, 512, 4, 4]      --                   True
# │    │    └─BatchNorm2d (norm)                [50, 1024, 9, 9]     [50, 1024, 9, 9]     2,048                True
# │    │    └─ReLU (relu)                       [50, 1024, 9, 9]     [50, 1024, 9, 9]     --                   --
# │    │    └─Conv2d (conv)                     [50, 1024, 9, 9]     [50, 512, 9, 9]      524,288              True
# │    │    └─AvgPool2d (pool)                  [50, 512, 9, 9]      [50, 512, 4, 4]      --                   --
# │    └─_DenseBlock (denseblock4)              [50, 512, 4, 4]      [50, 1024, 4, 4]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [50, 512, 4, 4]      [50, 32, 4, 4]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [50, 512, 4, 4]      [50, 32, 4, 4]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [50, 512, 4, 4]      [50, 32, 4, 4]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [50, 512, 4, 4]      [50, 32, 4, 4]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [50, 512, 4, 4]      [50, 32, 4, 4]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [50, 512, 4, 4]      [50, 32, 4, 4]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [50, 512, 4, 4]      [50, 32, 4, 4]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [50, 512, 4, 4]      [50, 32, 4, 4]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [50, 512, 4, 4]      [50, 32, 4, 4]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [50, 512, 4, 4]      [50, 32, 4, 4]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [50, 512, 4, 4]      [50, 32, 4, 4]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [50, 512, 4, 4]      [50, 32, 4, 4]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [50, 512, 4, 4]      [50, 32, 4, 4]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [50, 512, 4, 4]      [50, 32, 4, 4]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [50, 512, 4, 4]      [50, 32, 4, 4]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [50, 512, 4, 4]      [50, 32, 4, 4]       166,080              True
# │    └─BatchNorm2d (norm5)                    [50, 1024, 4, 4]     [50, 1024, 4, 4]     2,048                True
# ├─Sequential (classifier)                     [50, 1024]           [50, 4]              --                   True
# │    └─Linear (0)                             [50, 1024]           [50, 512]            524,800              True
# │    └─ReLU (1)                               [50, 512]            [50, 512]            --                   --
# │    └─Linear (2)                             [50, 512]            [50, 4]              2,052                True
# =============================================================================================================================
# Total params: 7,480,708
# Trainable params: 6,183,172
# Non-trainable params: 1,297,536
# Total mult-adds (G): 62.95
# =============================================================================================================================
# Input size (MB): 13.50
# Forward/backward pass size (MB): 4015.85
# Params size (MB): 29.92
# Estimated Total Size (MB): 4059.27
# =============================================================================================================================

# %%
rand_image_tensor = torch.randn(size=(3, 150, 150))
rand_image_tensor=rand_image_tensor.to(device)

# %%
# now trying to see the flatten shape
model1(rand_image_tensor.unsqueeze(0))
# Out:
# tensor([[0.0161, 0.0746, 0.4336, 0.3063]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
# from torch.optim.lr_scheduler import ReduceLROnPlateau
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model1.parameters(),lr=0.001)


# scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

# scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[6,10,15], gamma=0.001)

# %%
def train_benchmark(start:float, end:float, device:torch.device = None):
    """
    start: is the start time of the training benchmark

    end: is the end time of the training benchmark

    device: is the device which is going to run the training benchmark either 'cpu' or 'gpu' in case of mac m1 'mps'
    """
    print(f" training benchmark on {device} took {(end-start):.3f} seconds")

# %%
def accuracy_fn(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
train_loss_values=[]
train_acc_values= []

def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):



    # """Performs a training step with the model trying to learn on data_loader."""
  global train_loss_values
  global train_acc_values
  train_loss, train_acc = 0, 0

  # Put model into training mode
  model.train()

    # Add a loop to loop through the training batches
  for batch, (X, y) in enumerate(data_loader):
        # Put data on target device
      X, y = X.to(device), y.to(device)

        # 1. Forward pass (outputs the raw logits from the model)
      y_pred = model(X)

        # 2. Calculate loss and accuracy (per batch)
      loss = loss_fn(y_pred, y)
      train_loss += loss.item() # accumulate train loss
      train_acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1)) # go from logits -> prediction labels

        # 3. Optimizer zero grad
      optimizer.zero_grad()

        # 4. Loss backward
      loss.backward()

        # 5. Optimizer step (update the model's parameters once *per batch*)
      optimizer.step()
      # scheduler.step(train_loss)

    # Divide total train loss and acc by length of train dataloader
  train_loss /= len(data_loader)
  train_acc /= len(data_loader)
  train_loss_values.append(train_loss)
  train_acc_values.append(train_acc)
  print(f"Train loss: {train_loss:.5f} | Train acc: {train_acc:.2f}%")

# %%
validation_loss_values=[]
validation_acc_values=[]
def valid_step(model: torch.nn.Module,
              data_loader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):

    # """Performs a validation loop step on model going over data_loader."""

  global validation_loss_values
  global validation_acc_values
  valid_loss, valid_acc = 0, 0

    # Put the model in eval mode
  model.eval()

    # Turn on inference mode context manager
  with torch.inference_mode():

    for X, y in data_loader:

            # Send the data to the target device
      X, y = X.to(device), y.to(device)

            # 1. Forward pass (outputs raw logits)
      valid_pred = model(X)

            # 2. Calculate the loss and accuracy
      valid_loss += loss_fn(valid_pred, y)
      valid_acc += accuracy_fn(y_true=y, y_pred=valid_pred.argmax(dim=1))  # go from logits -> prediction labels

        # Adjust metrics and print out
    valid_loss /= len(data_loader)
    valid_acc /= len(data_loader)
    validation_loss_values.append(valid_loss)
    validation_acc_values.append(valid_acc)
    print(f"valid loss: {valid_loss:.5f} | valid acc: {valid_acc:.2f}%\n")

# %%
from timeit import default_timer as timer

start = timer()
EPOCHS= 30

for epoch in tqdm(range(EPOCHS)):
  print(f"Epoch: {epoch} \n......")

  train_step(model1,train_loader,loss_fn,optimizer,accuracy_fn,device)
  valid_step(model1,val_loader,loss_fn,accuracy_fn,device)



end =timer()
train_benchmark(start=start,end=end,device=str(next(model1.parameters()).device))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 0
# ......
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Train loss: 0.69937 | Train acc: 67.48%
# valid loss: 0.53088 | valid acc: 76.56%
#
# Epoch: 1
# ......
# Train loss: 0.50537 | Train acc: 77.59%
# valid loss: 0.47539 | valid acc: 79.13%
#
# Epoch: 2
# ......
# Train loss: 0.40664 | Train acc: 82.83%
# valid loss: 0.39430 | valid acc: 82.95%
#
# Epoch: 3
# ......
# Train loss: 0.35141 | Train acc: 84.98%
# valid loss: 0.34997 | valid acc: 85.15%
#
# Epoch: 4
# ......
# Train loss: 0.33423 | Train acc: 86.40%
# valid loss: 0.34160 | valid acc: 86.18%
#
# Epoch: 5
# ......
# Train loss: 0.26105 | Train acc: 89.23%
# valid loss: 0.28160 | valid acc: 88.97%
#
# Epoch: 6
# ......
# Train loss: 0.24988 | Train acc: 89.91%
# valid loss: 0.30671 | valid acc: 87.51%
#
# Epoch: 7
# ......
# Train loss: 0.19785 | Train acc: 92.18%
# valid loss: 0.25254 | valid acc: 90.38%
#
# Epoch: 8
# ......
# Train loss: 0.17565 | Train acc: 93.22%
# valid loss: 0.26206 | valid acc: 89.64%
#
# Epoch: 9
# ......
# Train loss: 0.15571 | Train acc: 94.29%
# valid loss: 0.30516 | valid acc: 89.62%
#
# Epoch: 10
# ......
# Train loss: 0.14414 | Train acc: 94.29%
# valid loss: 0.19149 | valid acc: 92.41%
#
# Epoch: 11
# ......
# Train loss: 0.12472 | Train acc: 95.16%
# valid loss: 0.21569 | valid acc: 90.77%
#
# Epoch: 12
# ......
# Train loss: 0.10785 | Train acc: 95.94%
# valid loss: 0.20314 | valid acc: 91.87%
#
# Epoch: 13
# ......
# Train loss: 0.10277 | Train acc: 96.36%
# valid loss: 0.15311 | valid acc: 94.56%
#
# Epoch: 14
# ......
# Train loss: 0.10183 | Train acc: 96.24%
# valid loss: 0.22525 | valid acc: 91.36%
#
# Epoch: 15
# ......
# Train loss: 0.10245 | Train acc: 96.30%
# valid loss: 0.17840 | valid acc: 93.54%
#
# Epoch: 16
# ......
# Train loss: 0.09981 | Train acc: 96.37%
# valid loss: 0.14716 | valid acc: 94.33%
#
# Epoch: 17
# ......
# Train loss: 0.07731 | Train acc: 97.04%
# valid loss: 0.13083 | valid acc: 95.10%
#
# Epoch: 18
# ......
# Train loss: 0.07770 | Train acc: 97.30%
# valid loss: 0.18974 | valid acc: 93.85%
#
# Epoch: 19
# ......
# Train loss: 0.08264 | Train acc: 97.16%
# valid loss: 0.14095 | valid acc: 94.74%
#
# Epoch: 20
# ......
# Train loss: 0.10324 | Train acc: 96.32%
# valid loss: 0.18926 | valid acc: 93.54%
#
# Epoch: 21
# ......
# Train loss: 0.06281 | Train acc: 97.64%
# valid loss: 0.16768 | valid acc: 94.08%
#
# Epoch: 22
# ......
# Train loss: 0.06778 | Train acc: 97.66%
# valid loss: 0.12658 | valid acc: 95.69%
#
# Epoch: 23
# ......
# Train loss: 0.05719 | Train acc: 97.98%
# valid loss: 0.11474 | valid acc: 95.97%
#
# Epoch: 24
# ......
# Train loss: 0.06395 | Train acc: 97.77%
# valid loss: 0.15561 | valid acc: 94.69%
#
# Epoch: 25
# ......
# Train loss: 0.06292 | Train acc: 97.86%
# valid loss: 0.12576 | valid acc: 95.31%
#
# Epoch: 26
# ......
# Train loss: 0.05979 | Train acc: 97.82%
# valid loss: 0.14820 | valid acc: 95.38%
#
# Epoch: 27
# ......
# Train loss: 0.04646 | Train acc: 98.21%
# valid loss: 0.15461 | valid acc: 95.38%
#
# Epoch: 28
# ......
# Train loss: 0.04648 | Train acc: 98.42%
# valid loss: 0.13092 | valid acc: 95.74%
#
# Epoch: 29
# ......
# Train loss: 0.05171 | Train acc: 98.22%
# valid loss: 0.22190 | valid acc: 93.31%
#
#  training benchmark on cuda:0 took 1093.683 seconds

# %%
# let's plot the train and test loss functions
len(train_acc_values)
epochs = list(range(0,len(train_loss_values)))

# Plot the losses
plt.plot(epochs, torch.tensor(train_loss_values).cpu(), label='Training Loss')
plt.plot(epochs, torch.tensor(validation_loss_values).cpu(), label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# accuracylen(train_acc_values)
epochs = list(range(0,len(train_acc_values)))

# Plot the losses
plt.plot(epochs, torch.tensor(train_acc_values).cpu(), label='Training accuracy')
plt.plot(epochs, torch.tensor(validation_acc_values).cpu(), label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
def make_predictions(model: torch.nn.Module,
                     data: list,
                     device: torch.device = device):
  pred_probs = []
  model.to(device)
  model.eval()
  with torch.inference_mode():
    for sample in data:
      # Prepare the sample (add a batch dimension and pass to target device)
      sample = torch.unsqueeze(sample, dim=0).to(device)

      # Forward pass (model outputs raw logits)
      pred_logit = model(sample)

      # Get prediction probability (logit -> prediction probability)
      pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)

      # Get pred_prob off the GPU for further calculations
      pred_probs.append(pred_prob.cpu())

  # Stack the pred_probs to turn list into a tensor
  return torch.stack(pred_probs)

# %%
import random
# random.seed(42)
print(len(test_dataset))
test_samples = []
test_labels = []
for sample, label in random.sample(list(test_dataset), k=1920):
  test_samples.append(sample)
  test_labels.append(label)

# View the first sample shape
test_samples[0].shape
# Out:
# 1920
# torch.Size([3, 150, 150])

# %%
pred_probs = make_predictions(model=model1,
                              data=test_samples)

# View first two prediction probabilities
pred_probs[:2]
# Out:
# tensor([[3.7624e-04, 1.9524e-07, 1.3848e-06, 9.9962e-01],
#         [5.0259e-01, 1.5733e-04, 7.0270e-03, 4.9022e-01]])

# %%
pred_classes = pred_probs.argmax(dim=1)
pred_classes
# Out:
# tensor([3, 0, 3,  ..., 1, 0, 0])

# %%
array_test_labels =[]

for item in test_labels:

  array_test_labels.append(item.item())

# array_test_labels

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay,roc_curve,RocCurveDisplay
comparison= {
    'predicted_labels':pred_classes,
    'true labels':array_test_labels
}

import pandas as pd

df= pd.DataFrame(data=comparison)

df.head(50)

accuracy_score(test_labels,pred_classes)*100
# Out:
# 94.01041666666666

# %%
df.head(20)
# Out:
#     predicted_labels  true labels
# 0                  3            3
# 1                  0            3
# 2                  3            3
# 3                  0            0
# 4                  0            0
# 5                  3            3
# 6                  0            0
# 7                  0            0
# 8                  0            3
# 9                  0            0
# 10                 2            2
# 11                 1            1
# 12                 0            0
# 13                 0            0
# 14                 1            1
# 15                 1            1
# 16                 1            1
# 17                 3            3
# 18                 1            1
# 19                 2            2

# %%
cm = confusion_matrix(pred_classes,array_test_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
fig, ax = plt.subplots(figsize=(8,8))
disp.plot(ax=ax)
print(classification_report(pred_classes,array_test_labels))
print(class_idx)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       500
#            1       1.00      1.00      1.00       479
#            2       0.87      0.96      0.91       449
#            3       0.91      0.87      0.89       492
#
#     accuracy                           0.94      1920
#    macro avg       0.94      0.94      0.94      1920
# weighted avg       0.94      0.94      0.94      1920
#
# {'MildDemented': 0, 'ModerateDemented': 1, 'NonDemented': 2, 'VeryMildDemented': 3}

# %%
# Create model dictory path
MODEL_PATH = Path(f"{path}/models")
MODEL_PATH.mkdir(parents=True,
                 exist_ok=True)

# Create model save
MODEL_NAME = "Densenet121_v3.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model1.state_dict(),
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: None/models/Densenet121_v3.pth
